# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
#
# Use text editor to edit the script and type in valid Instagram username/password

from InstagramAPI import InstagramAPI
import time
from datetime import datetime

# %%
media_id = '1477006830906870775_19343908'

# stop conditions, the script will end when first of them will be true
until_date = '2017-03-31'
count = 100

API = InstagramAPI("victordesanunes", "rollerdabatata13")
API.login()
# Out:
# Request return 429 error!
# {'message': 'Please wait a few minutes before you try again.', 'status': 'fail'}
# Login success!
# True

# %%
API.getMediaComments()

# %%
API.LastJson['comments']
# Out:
# [{'bit_flags': 0,
#   'comment_like_count': 0,
#   'content_type': 'comment',
#   'created_at': 1492856718,
#   'created_at_utc': 1492856718,
#   'did_report_as_spam': False,
#   'has_liked_comment': False,
#   'inline_composer_display_condition': 'never',
#   'pk': 17877877459060171,
#   'status': 'Active',
#   'text': 'Самая красивая',
#   'type': 0,
#   'user': {'full_name': 'Вадим Вадим',
#    'is_private': False,
#    'is_verified': False,
#    'pk': 4516793910,
#    'profile_pic_id': '1434713552757027272_4516793910',
#    'profile_pic_url': 'https://instagram.fsjk2-1.fna.fbcdn.net/vp/71b6f07c6742a35e319cb8d2f6638d5e/5BA193E5/t51.2885-19/s150x150/16123486_156258244872863_2958493045374320640_a.jpg',
#    'username': 'vadim_gorgadze'},
#   'user_id': 4516793910},
#  {'bit_flags': 0,
#   'comment_like_count': 0,
#   'content_type': 'comment',
#   'created_at': 1492856730,
#   'created_at_utc': 1492856730,
#   'did_report_as_spam': False,
#   'has_liked_comment': False,
#   'inline_composer_display_condition': 'never',
#   'pk': 17869501615076315,
#   'status': 'Active',
#   'text': 'Только не худей больше',
#   'type': 0,
#   'user': {'full_name': 'Вадим Вадим',
#    'is_private': False,
#    'is_verified': False,
#    'pk': 4516793910,
#    'profile_pic_id': '1434713552757027272_4516793910',
#    'profile_pic_url': 'https://instagram.fsjk2-1.fna.fbcdn.net/vp/71b6f07c6742a35e319cb8d2f6638d5e/5BA193E5/t51.2885-19/s150x150/16123486_156258244872863_2958493045374320640_a.jpg',
#    'username': 'vadim_gorgadze'},
#   'user_id': 4516793910},
#  {'bit_flags': 0,
#   'comment_like_count': 0,
#   'content_type': 'comment',
#   'created_at': 1493113672,
#   'created_at_utc': 1493113672,
#   'did_report_as_spam': False,
#   'has_liked_comment': False,
#   'inline_composer_display_condition': 'never',
#   'pk': 17878397614047005,
#   'status': 'Active',
#   'text': '@te_weezi187 @mr.nice_pockets @archetto_maxout',
#   'type': 0,
#   'user': {'full_name': '#SahaRussia #Volgograd34',
#    'is_private': False,
#    'is_verified': False,
#    'pk': 1504779277,
#    'profile_pic_id': '1785479321293886920_1504779277',
#    'profile_pic_url': 'https://instagram.fsjk2-1.fna.fbcdn.net/vp/4b30095d0cdb275aa59ed7a3fc5867b5/5B96B0AD/t51.2885-19/s150x150/32152033_227161157868654_8667017976379080704_n.jpg',
#    'username': 'efremkinmax'},
#   'user_id': 1504779277},
#  {'bit_flags': 0,
#   'comment_like_count': 0,
#   'content_type': 'comment',
#   'created_at': 1493113713,
#   'created_at_utc': 1493113713,
#   'did_report_as_spam': False,
#   'has_liked_comment': False,
#   'inline_composer_display_condition': 'never',
#   'pk': 17873865097068126,
#   'status': 'Active',
#   'text': '@te_weez187',
#   'type': 0,
#   'user': {'full_name': '#SahaRussia #Volgograd34',
#    'is_private': False,
#    'is_verified': False,
#    'pk': 1504779277,
#    'profile_pic_id': '1785479321293886920_1504779277',
#    'profile_pic_url': 'https://instagram.fsjk2-1.fna.fbcdn.net/vp/4b30095d0cdb275aa59ed7a3fc5867b5/5B96B0AD/t51.2885-19/s150x150/32152033_227161157868654_8667017976379080704_n.jpg',
#    'username': 'efremkinmax'},
#   'user_id': 1504779277},
#  {'bit_flags': 0,
#   'comment_like_count': 0,
#   'content_type': 'comment',
#   'created_at': 1494223144,
#   'created_at_utc': 1494223144,
#   'did_report_as_spam': False,
#   'has_liked_comment': False,
#   'inline_composer_display_condition': 'never',
#   'pk': 17879988322038283,
#   'status': 'Active',
#   'text': 'Super',
#   'type': 0,
#   'user': {'full_name': 'Дима Беляев',
#    'is_private': False,
#    'is_verified': False,
#    'pk': 498071025,
#    'profile_pic_url': 'https://instagram.fsjk2-1.fna.fbcdn.net/vp/0c12947a871d52b3d36a1cade5ef3c73/5B7FB13B/t51.2885-19/s150x150/12142305_1668859983373282_1909602927_a.jpg',
#    'username': 'dbelayev'},
#   'user_id': 498071025},
#  {'bit_flags': 0,
#   'comment_like_count': 0,
#   'content_type': 'comment',
#   'created_at': 1494248411,
#   'created_at_utc': 1494248411,
#   'did_report_as_spam': False,
#   'has_liked_comment': False,
#   'inline_composer_display_condition': 'never',
#   'pk': 17855374534179170,
#   'status': 'Active',
#   'text': 'я твоя паклоница😘😘',
#   'type': 0,
#   'user': {'full_name': 'Багай-оол Чынапай',
#    'is_private': False,
#    'is_verified': False,
#    'pk': 4922014788,
#    'profile_pic_url': 'https://instagram.fztf1-1.fna.fbcdn.net/vp/856b9478629f7c2f4ae549c4c8cc5dd7/5B94597A/t51.2885-19/11906329_960233084022564_1448528159_a.jpg',
#    'username': 'chynapai'},
#   'user_id': 4922014788},
#  {'bit_flags': 0,
#   'comment_like_count': 0,
#   'content_type': 'comment',
#   'created_at': 1494649071,
#   'created_at_utc': 1494649071,
#   'did_report_as_spam': False,
#   'has_liked_comment': False,
#   'inline_composer_display_condition': 'never',
#   'pk': 17880714673024531,
#   'status': 'Active',
#   'text': 'САМАЯ КРАСИВАЯ 😍😍😍',
#   'type': 0,
#   'user': {'full_name': '- Erika Herceg',
#    'is_private': False,
#    'is_verified': False,
#    'pk': 3183872354,
#    'profile_pic_id': '1529881742835878741_3183872354',
#    'profile_pic_url': 'https://instagram.fsjk2-1.fna.fbcdn.net/vp/3f4aeb0d8035621ad916ffac815af7b6/5B89BAD5/t51.2885-19/s150x150/18811953_1488978944506024_1679527371754962944_a.jpg',
#    'username': 'erika_teams'},
#   'user_id': 3183872354},
#  {'bit_flags': 0,
#   'comment_like_count': 0,
#   'content_type': 'comment',
#   'created_at': 1495351281,
#   'created_at_utc': 1495351281,
#   'did_report_as_spam': False,
#   'has_liked_comment': False,
#   'inline_composer_display_condition': 'never',
#   'pk': 17881998010063103,
#   'status': 'Active',
#   'text': 'Только не худей больше!!!!',
#   'type': 0,
#   'user': {'full_name': '',
#    'is_private': True,
#    'is_verified': False,
#    'pk': 4619573641,
#    'profile_pic_id': '1771589761124557741_4619573641',
#    'profile_pic_url': 'https://instagram.fsjk2-1.fna.fbcdn.net/vp/692d59ef580ea7ec3686b5fde1b914ca/5BA07A52/t51.2885-19/s150x150/31386898_1747299448641508_152477025544699904_n.jpg',
#    'username': 'z.rusalinaa'},
#   'user_id': 4619573641},
#  {'bit_flags': 0,
#   'comment_like_count': 0,
#   'content_type': 'comment',
#   'created_at': 1497148886,
#   'created_at_utc': 1497148886,
#   'did_report_as_spam': False,
#   'has_liked_comment': False,
#   'inline_composer_display_condition': 'never',
#   'pk': 17859905761146730,
#   'status': 'Active',
#   'text': 'Й не ухоюенность красы личика и фигуру и озорство а супер эго в сторону людины простой',
#   'type': 0,
#   'user': {'full_name': 'Evgeny Kurilov',
#    'is_private': False,
#    'is_verified': False,
#    'pk': 3539403842,
#    'profile_pic_id': '1484125094208824069_3539403842',
#    'profile_pic_url': 'https://instagram.fsjk2-1.fna.fbcdn.net/vp/f2df758e49d34d646dbb844669f3b518/5B885904/t51.2885-19/s150x150/17661998_287206545054407_8301279108575264768_a.jpg',
#    'username': 'evgenykurilov_czech'},
#   'user_id': 3539403842},
#  {'bit_flags': 0,
#   'comment_like_count': 0,
#   'content_type': 'comment',
#   'created_at': 1498021849,
#   'created_at_utc': 1498021849,
#   'did_report_as_spam': False,
#   'has_liked_comment': False,
#   'inline_composer_display_condition': 'never',
#   'pk': 17859950176160002,
#   'status': 'Active',
#   'text': 'To da unlimited stupis',
#   'type': 0,
#   'user': {'full_name': 'Evgeny Kurilov',
#    'is_private': False,
#    'is_verified': False,
#    'pk': 3539403842,
#    'profile_pic_id': '1484125094208824069_3539403842',
#    'profile_pic_url': 'https://instagram.fsjk2-1.fna.fbcdn.net/vp/f2df758e49d34d646dbb844669f3b518/5B885904/t51.2885-19/s150x150/17661998_287206545054407_8301279108575264768_a.jpg',
#    'username': 'evgenykurilov_czech'},
#   'user_id': 3539403842},
#  {'bit_flags': 0,
#   'comment_like_count': 0,
#   'content_type': 'comment',
#   'created_at': 1498022002,
#   'created_at_utc': 1498022002,
#   'did_report_as_spam': False,
#   'has_liked_comment': False,
#   'inline_composer_display_condition': 'never',
#   'pk': 17860955335149115,
#   'status': 'Active',
#   'text': 'Stopis to u vas v pacastunky hlavi musli a u nas stupis to...',
#   'type': 0,
#   'user': {'full_name': 'Evgeny Kurilov',
#    'is_private': False,
#    'is_verified': False,
#    'pk': 3539403842,
#    'profile_pic_id': '1484125094208824069_3539403842',
#    'profile_pic_url': 'https://instagram.fsjk2-1.fna.fbcdn.net/vp/f2df758e49d34d646dbb844669f3b518/5B885904/t51.2885-19/s150x150/17661998_287206545054407_8301279108575264768_a.jpg',
#    'username': 'evgenykurilov_czech'},
#   'user_id': 3539403842},
#  {'bit_flags': 0,
#   'comment_like_count': 0,
#   'content_type': 'comment',
#   'created_at': 1498022200,
#   'created_at_utc': 1498022200,
#   'did_report_as_spam': False,
#   'has_liked_comment': False,
#   'inline_composer_display_condition': 'never',
#   'pk': 17858968120193653,
#   'status': 'Active',
#   'text': 'Stupis to leto ne mae roky',
#   'type': 0,
#   'user': {'full_name': 'Evgeny Kurilov',
#    'is_private': False,
#    'is_verified': False,
#    'pk': 3539403842,
#    'profile_pic_id': '1484125094208824069_3539403842',
#    'profile_pic_url': 'https://instagram.fsjk2-1.fna.fbcdn.net/vp/f2df758e49d34d646dbb844669f3b518/5B885904/t51.2885-19/s150x150/17661998_287206545054407_8301279108575264768_a.jpg',
#    'username': 'evgenykurilov_czech'},
#   'user_id': 3539403842},
#  {'bit_flags': 0,
#   'comment_like_count': 0,
#   'content_type': 'comment',
#   'created_at': 1498022229,
#   'created_at_utc': 1498022229,
#   'did_report_as_spam': False,
#   'has_liked_comment': False,
#   'inline_composer_display_condition': 'never',
#   'pk': 17860191616164369,
#   'status': 'Active',
#   'text': 'Pani jupe maladenka)',
#   'type': 0,
#   'user': {'full_name': 'Evgeny Kurilov',
#    'is_private': False,
#    'is_verified': False,
#    'pk': 3539403842,
#    'profile_pic_id': '1484125094208824069_3539403842',
#    'profile_pic_url': 'https://instagram.fsjk2-1.fna.fbcdn.net/vp/f2df758e49d34d646dbb844669f3b518/5B885904/t51.2885-19/s150x150/17661998_287206545054407_8301279108575264768_a.jpg',
#    'username': 'evgenykurilov_czech'},
#   'user_id': 3539403842},
#  {'bit_flags': 0,
#   'comment_like_count': 0,
#   'content_type': 'comment',
#   'created_at': 1500283345,
#   'created_at_utc': 1500283345,
#   'did_report_as_spam': False,
#   'has_liked_comment': False,
#   'inline_composer_display_condition': 'never',
#   'pk': 17874692050084737,
#   'status': 'Active',
#   'text': 'Типо 13 лет',
#   'type': 0,
#   'user': {'full_name': 'STYLE • PIXIE • FLATLAY ...',
#    'is_private': False,
#    'is_verified': False,
#    'latest_reel_media': 1527095851,
#    'pk': 1099705087,
#    'profile_pic_id': '1778199188208476803_1099705087',
#    'profile_pic_url': 'https://instagram.fsjk2-1.fna.fbcdn.net/vp/33233c9e3aa977faa92fcf63cb647a0d/5BA2345C/t51.2885-19/s150x150/31897726_1897571517199673_73060065174618112_n.jpg',
#    'username': 'nomsuar'},
#   'user_id': 1099705087},
#  {'bit_flags': 0,
#   'comment_like_count': 0,
#   'content_type': 'comment',
#   'created_at': 1501777690,
#   'created_at_utc': 1501777690,
#   'did_report_as_spam': False,
#   'has_liked_comment': False,
#   'inline_composer_display_condition': 'never',
#   'pk': 17893666360018817,
#   'status': 'Active',
#   'text': 'Вера, оставайтесь всегда такой обаятельной!!!',
#   'type': 0,
#   'user': {'full_name': 'Евгений Летний',
#    'is_private': False,
#    'is_verified': False,
#    'pk': 5823676734,
#    'profile_pic_id': '1761805442171857703_5823676734',
#    'profile_pic_url': 'https://instagram.fsjk2-1.fna.fbcdn.net/vp/4b4da2efd6718844fc2f2e7531572e1d/5B84F037/t51.2885-19/s150x150/30087874_1659566484099141_6635160860941615104_n.jpg',
#    'username': 'evgeniyletniy'},
#   'user_id': 5823676734},
#  {'bit_flags': 0,
#   'comment_like_count': 0,
#   'content_type': 'comment',
#   'created_at': 1505200824,
#   'created_at_utc': 1505200824,
#   'did_report_as_spam': False,
#   'has_liked_comment': False,
#   'inline_composer_display_condition': 'never',
#   'pk': 17897280382051256,
#   'status': 'Active',
#   'text': 'люблю',
#   'type': 0,
#   'user': {'full_name': 'Султан Аширбекоч',
#    'is_private': False,
#    'is_verified': False,
#    'pk': 5896894964,
#    'profile_pic_url': 'https://instagram.fztf1-1.fna.fbcdn.net/vp/856b9478629f7c2f4ae549c4c8cc5dd7/5B94597A/t51.2885-19/11906329_960233084022564_1448528159_a.jpg',
#    'username': 'sultana4050'},
#   'user_id': 5896894964},
#  {'bit_flags': 0,
#   'comment_like_count': 0,
#   'content_type': 'comment',
#   'created_at': 1505718197,
#   'created_at_utc': 1505718197,
#   'did_report_as_spam': False,
#   'has_liked_comment': False,
#   'inline_composer_display_condition': 'never',
#   'pk': 17886555775112640,
#   'status': 'Active',
#   'text': 'Good',
#   'type': 0,
#   'user': {'full_name': 'Миасс Православный',
#    'is_private': False,
#    'is_verified': False,
#    'pk': 6033958054,
#    'profile_pic_id': '1602870269742399503_6033958054',
#    'profile_pic_url': 'https://instagram.fsjk2-1.fna.fbcdn.net/vp/b19c4de18eb5c5ef239cc7f49e947e40/5B84F785/t51.2885-19/s150x150/21436215_273122613204090_296115442185928704_n.jpg',
#    'username': 'pravmiass'},
#   'user_id': 6033958054}]

# %%
API.getUsernameInfo()
has_more_comments = True
max_id = ''
comments = []

while has_more_comments:
    _ = API.getMediaComments(media_id, max_id=max_id)
    # comments' page come from older to newer, lets preserve desc order in full list
    for c in reversed(API.LastJson['comments']):
        comments.append(c)
    has_more_comments = API.LastJson.get('has_more_comments', False)
    # evaluate stop conditions
    if count and len(comments) >= count:
        comments = comments[:count]
        # stop loop
        has_more_comments = False
        print ("stopped by count")
    if until_date:
        older_comment = comments[-1]
        dt = datetime.utcfromtimestamp(older_comment.get('created_at_utc', 0))
        # only check all records if the last is older than stop condition
        if dt.isoformat() <= until_date:
            # keep comments after until_date
            comments = [
                c
                for c in comments
                if datetime.utcfromtimestamp(c.get('created_at_utc', 0)) > until_date
            ]
            # stop loop
            has_more_comments = False
            print( "stopped by until_date")
    # next page
    if has_more_comments:
        max_id = API.LastJson.get('next_max_id', '')
time.sleep(2)
# Out:
# Request return 429 error!
# {'message': 'Please wait a few minutes before you try again.', 'status': 'fail'}
# Login success!
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-b9ea58134cbe> in <module>()
#       7 API = InstagramAPI("victordesanunes", "rollerdabatata13")
#       8 API.login()
# ----> 9 API.getUsernameInfo()
#      10 has_more_comments = True
#      11 max_id = ''
#
# TypeError: getUsernameInfo() missing 1 required positional argument: 'usernameId'
